# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("C:/Users/win 10/Downloads/archive/Iris.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
df.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
sns.displot(df["SepalLengthCm"],bins=[4,4.5,5,5.5,6,6.5,7,7.5,8])
plt.show()

# %%
sns.displot(df["SepalWidthCm"],bins=[4,4.5,5,5.5,6,6.5,7,7.5,8])
plt.show()

# %%
sns.displot(df["PetalLengthCm"],bins=[4,4.5,5,5.5,6,6.5,7,7.5,8])
plt.show()

# %%
sns.displot(df["PetalWidthCm"],bins=[4,4.5,5,5.5,6,6.5,7,7.5,8])
plt.show()

# %%
sns.barplot(x=df.Species, y = df.PetalLengthCm)
# Out:
# <Axes: xlabel='Species', ylabel='PetalLengthCm'>

# %%
sns.barplot(x=df.Species, y = df.SepalLengthCm)
# Out:
# <Axes: xlabel='Species', ylabel='SepalLengthCm'>

# %%
sns.barplot(x=df.SepalLengthCm, y = df.PetalLengthCm )
# Out:
# <Axes: xlabel='SepalLengthCm', ylabel='PetalLengthCm'>

# %%
sns.barplot(x=df.SepalLengthCm, y = df.PetalLengthCm, hue = df.Species)
# Out:
# <Axes: xlabel='SepalLengthCm', ylabel='PetalLengthCm'>
